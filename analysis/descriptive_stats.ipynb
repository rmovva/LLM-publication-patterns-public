# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os, sys
sys.path.append('./analysis/')

# %load_ext autoreload
# %autoreload 2
import utils
from utils import RECENT_DATE_THRESHOLD

# %% [markdown]
# ### Save annotated dataframe for public release of data (only run once)

# %%
# Add citation data at the end of the dataframe
lm_metadata = utils.annotate_lm_metadata()
lm_metadata = lm_metadata[[c for c in lm_metadata.columns if c != 'citationCount'] + ['citationCount']]
lm_metadata = utils.convert_citations_to_ranks(lm_metadata, month_window_sizes=[3, 12])
lm_metadata.id = lm_metadata.id.apply(lambda x: f'arXiv:{x}') # add arXiv prefix to ids
display(lm_metadata.sample(5))

# # Save the dataframe (this will include all the annotations we use in our analyses)
# lm_metadata.to_json(os.path.join(utils.PROCESSED_DATA_DIR, 'lm_metadata_all_annotations.json'),
#                     orient='records', lines=True)
# Out:
# Papers with S2 data: 16924 out of 16979 (99.7%)
# Papers with an identified affiliation: 11688 out of 16979 (68.8%)
#                      id                                            authors  \
# 4552   arXiv:2105.08021  [Qingyun Wang, Semih Yavuz, Victoria Lin, Heng...
# 9483   arXiv:2210.12574  [Koustuv Sinha, Amirhossein Kazemnejad, Siva R...
# 13412  arXiv:2305.13478        [Joseph Marvin Imperial, Ekaterina Kochmar]
# 7860   arXiv:2205.10674  [Shushan Arakelyan, Anna Hakhverdyan, Miltiadi...
# 10954  arXiv:2302.04012  [Hossein Hajipour, Thorsten Holz, Lea Schönher...
#
#                                                    title  \
# 4552   Stage-wise Fine-tuning for Graph-to-Text Gener...
# 9483    The Curious Case of Absolute Position Embeddings
# 13412  Automatic Readability Assessment for Closely R...
# 7860            NS3: Neuro-Symbolic Semantic Code Search
# 10954  Systematically Finding Security Vulnerabilitie...
#
#                                 categories  \
# 4552                        [cs.CL, cs.AI]
# 9483                        [cs.CL, cs.LG]
# 13412                              [cs.CL]
# 7860                               [cs.LG]
# 10954  [cs.CR, cs.AI, cs.CL, cs.LG, cs.SE]
#
#                                                 abstract  \
# 4552     Graph-to-text generation has benefited from ...
# 9483     Transformer language models encode the notio...
# 13412    In recent years, the main focus of research ...
# 7860     Semantic code search is the task of retrievi...
# 10954    Recently, large language models for code gen...
#
#                                                 versions first_category  \
# 4552   [{'version': 'v1', 'created': 'Mon, 17 May 202...          cs.CL
# 9483   [{'version': 'v1', 'created': 'Sun, 23 Oct 202...          cs.CL
# 13412  [{'version': 'v1', 'created': 'Mon, 22 May 202...          cs.CL
# 7860   [{'version': 'v1', 'created': 'Sat, 21 May 202...          cs.LG
# 10954  [{'version': 'v1', 'created': 'Wed, 8 Feb 2023...          cs.CR
#
#                   v1_date                        LM_related_terms  \
# 4552  2021-05-17 17:15:29                        [language model]
# 9483  2022-10-23 00:00:04                        [language model]
# 13412 2023-05-22 20:42:53                        [language model]
# 7860  2022-05-21 20:55:57                        [language model]
# 10954 2023-02-08 11:54:07  [language model, large language model]
#
#        mentions_LM_keyword                               cluster  \
# 4552                  True      Knowledge Graphs and Commonsense
# 9483                  True    Representations, Syntax, Semantics
# 13412                 True  Translation & Low-Resource Languages
# 7860                  True                       Code Generation
# 10954                 True           Privacy & Adversarial Risks
#
#                                       domains  industry  academic  \
# 4552   [fb.com, illinois.edu, salesforce.com]      True      True
# 9483                              [mcgill.ca]     False      True
# 13412              [bath.ac.uk, mbzuai.ac.ae]     False      True
# 7860                 [usc.edu, allamanis.com]     False      True
# 10954                                      []     False     False
#
#        citationCount  percentile_rank_in_3_month_window  \
# 4552            13.0                           0.569714
# 9483             5.0                           0.691117
# 13412            0.0                           0.199259
# 7860             1.0                           0.188462
# 10954            6.0                           0.725700
#
#        percentile_rank_in_12_month_window
# 4552                             0.629011
# 9483                             0.584592
# 13412                            0.228022
# 7860                             0.249245
# 10954                            0.863389

# %%
lm_metadata_v2 = utils.load_annotated_lm_metadata()

# %%
# Print rows of lm_metadata that have academic == False but lm_metadata_v2 has academic == True
lm_metadata[(lm_metadata.academic == False) & (lm_metadata_v2.academic == True)]
# Out:
# Empty DataFrame
# Columns: [id, authors, title, categories, abstract, versions, first_category, v1_date, LM_related_terms, mentions_LM_keyword, cluster, domains, industry, academic, citationCount, percentile_rank_in_3_month_window, percentile_rank_in_12_month_window]
# Index: []

# %%
# Find domains that are in lm_metadata_v2 but not in lm_metadata
domains_in_lm_metadata_v2 = lm_metadata_v2.explode('domains').domains.unique()
domains_in_lm_metadata = lm_metadata.explode('domains').domains.unique()

domains_in_lm_metadata_v2_but_not_in_lm_metadata = set(domains_in_lm_metadata_v2) - set(domains_in_lm_metadata)
print(f'{len(domains_in_lm_metadata_v2_but_not_in_lm_metadata)} domains in lm_metadata_v2 but not in lm_metadata')
print(domains_in_lm_metadata_v2_but_not_in_lm_metadata)

domains_in_lm_metadata_but_not_in_lm_metadata_v2 = set(domains_in_lm_metadata) - set(domains_in_lm_metadata_v2)
print(f'{len(domains_in_lm_metadata_but_not_in_lm_metadata_v2)} domains in lm_metadata but not in lm_metadata_v2')
print(domains_in_lm_metadata_but_not_in_lm_metadata_v2)
# Out:
# 4 domains in lm_metadata_v2 but not in lm_metadata
# {'toronto.edu', 'cuhk.edu.cn', 'se.cuhk.edu.hk.com', 'cuhk.edu.hk'}
# 1 domains in lm_metadata but not in lm_metadata_v2
# {'cuhk.edu'}

# %%
# Print all domains with cuhk.edu in them in domain_counts_v2
domains_in_lm_metadata_v2 = set(lm_metadata_v2.explode('domains').domains.unique())
for d in domains_in_lm_metadata_v2:
    if not isinstance(d, str):
        print(d)
        continue
    if isinstance(d, str) and "cuhk.edu" in d:
        print(d)
# Out:
# nan
# cuhk.edu.hk
# se.cuhk.edu.hk.com
# cuhk.edu.cn

# %%
domain_counts_v2 = lm_metadata_v2.explode('domains').domains.value_counts()
domain_counts = lm_metadata.explode('domains').domains.value_counts()

for domain in domains_in_lm_metadata_v2_but_not_in_lm_metadata:
    print(domain)
    print(domain_counts_v2[domain])
    # print(domain_counts[domain])
    print()
# Out:
# toronto.edu
# 55
#
# cuhk.edu.cn
# 30
#
# se.cuhk.edu.hk.com
# 1
#
# cuhk.edu.hk
# 93

# %%
# Display rows in lm_metadata_v2 where 'u-tokyo.ac' is in the list of domains
display(lm_metadata_v2[lm_metadata_v2.domains.apply(lambda x: 'bits-pilani.ac.in' in x)])
# Out:
#                      id                                            authors  \
# 1676   arXiv:2003.13821  [Ayush Jain, Dr. N. M. Meenachi, Dr. B. Venkat...
# 2174   arXiv:2006.00593       [Rajaswa Patil, Somesh Singh, Swati Agarwal]
# 2175   arXiv:2006.00607                 [Siddhant Mahurkar, Rajaswa Patil]
# 2246   arXiv:2006.08870               [Ahan M. R., Shreyas Sunil Kulkarni]
# 3535   arXiv:2012.14427     [Mohit Sewak, Sanjay K. Sahay, Hemant Rathore]
# 3743   arXiv:2101.11891  [Shreya Gupta, Parantak Singh, Megha Sundriyal...
# 3901   arXiv:2102.12254  [Gunjan Chhablani, Abheesht Sharma, Harshit Pa...
# 3902   arXiv:2102.12255  [Abheesht Sharma, Harshit Pandey, Gunjan Chhab...
# 3923   arXiv:2103.00380                  [Abheesht Sharma, Harshit Pandey]
# 3936   arXiv:2103.00854  [Rajaswa Patil, Jasleen Dhillon, Siddhant Mahu...
# 4093   arXiv:2103.15764  [Usha Lokala, Francois Lamy, Triyasha Ghosh Da...
# 5576   arXiv:2109.07140  [Shaily Bhatt, Poonam Goyal, Sandipan Dandapat...
# 5695   arXiv:2109.11010  [Akshay Valsaraj, Ithihas Madala, Nikhil Garg,...
# 5705   arXiv:2109.11500     [Mohit Sewak, Sanjay K. Sahay, Hemant Rathore]
# 6836   arXiv:2202.04876                 [Devansh Jain, Luis Espinosa Anke]
# 7183   arXiv:2203.11856  [Usha Lokala, Aseem Srivastava, Triyasha Ghosh...
# 7227   arXiv:2203.14267                   [Vitthal Bhandari, Poonam Goyal]
# 8197   arXiv:2206.08680  [Shaz Furniturewala, Vijay Kumari, Amulya Ratn...
# 8209   arXiv:2206.09259              [Tarun Garg, Kaushik Roy, Amit Sheth]
# 8448   arXiv:2207.07706  [Shounak Naik, Rajaswa Patil, Swati Agarwal, V...
# 10238  arXiv:2212.05356          [Abhinav Rao, Ho Thi-Nga, Chng Eng-Siong]
# 12298  arXiv:2304.10512  [Usha Lokala, Orchid Chetia Phukan, Triyasha G...
# 12732  arXiv:2305.04100  [Anshika Gupta, Shaz Furniturewala, Vijay Kuma...
# 12783  arXiv:2305.04989  [Kaushik Roy, Tarun Garg, Vedant Palit, Yuxin ...
# 16077  arXiv:2308.04178  [Basabdatta Sen Bhattacharya, Vibhav Sinai Pis...
# 16175  arXiv:2308.06272  [Vinay Chamola, Gaurang Bansal, Tridib Kumar D...
# 16609  arXiv:2308.13538  [M Charity, Yash Bhartia, Daniel Zhang, Ahmed ...
#
#                                                    title  \
# 1676   NukeBERT: A Pre-trained language model for Low...
# 2174   BPGC at SemEval-2020 Task 11: Propaganda Detec...
# 2175   LRG at SemEval-2020 Task 7: Assessing the Abil...
# 2246   End-to-End Code Switching Language Models for ...
# 3535   Assessment of the Relative Importance of diffe...
# 3743   LESA: Linguistic Encapsulation and Semantic Am...
# 3901   NLRG at SemEval-2021 Task 5: Toxic Spans Detec...
# 3902   LRG at SemEval-2021 Task 4: Improving Reading ...
# 3923   LRG at TREC 2020: Document Ranking with XLNet-...
# 3936   Vy\=akarana: A Colorless Green Benchmark for S...
# 4093   eDarkTrends: Harnessing Social Media Trends in...
# 5576   On the Universality of Deep Contextual Languag...
# 5695   Alzheimers Dementia Detection using Acoustic &...
# 5705   LSTM Hyper-Parameter Selection for Malware Det...
# 6836   Distilling Hypernymy Relations from Language M...
# 7183   A Computational Approach to Understand Mental ...
# 7227   bitsa_nlp@LT-EDI-ACL2022: Leveraging Pretraine...
# 8197   BITS Pilani at HinglishEval: Quality Evaluatio...
# 8209   Can Language Models Capture Graph Semantics? F...
# 8448   Probing Semantic Grounding in Language Models ...
# 10238  Punctuation Restoration for Singaporean Spoken...
# 12298  "Can We Detect Substance Use Disorder?": Knowl...
# 12732  Rhetorical Role Labeling of Legal Documents us...
# 12783  Knowledge Graph Guided Semantic Evaluation of ...
# 16077  Assistive Chatbots for healthcare: a succinct ...
# 16175  Beyond Reality: The Pivotal Role of Generative...
# 16609  A Preliminary Study on a Conceptual Game Featu...
#
#                     categories  \
# 1676          [cs.LG, stat.ML]
# 2174                   [cs.CL]
# 2175                   [cs.CL]
# 2246   [cs.CL, cs.SD, eess.AS]
# 3535            [cs.CR, cs.LG]
# 3743                   [cs.CL]
# 3901            [cs.CL, cs.LG]
# 3902            [cs.CL, cs.LG]
# 3923     [cs.IR, cs.CL, cs.LG]
# 3936                   [cs.CL]
# 4093                   [cs.AI]
# 5576                   [cs.CL]
# 5695     [cs.CL, cs.LG, cs.SD]
# 5705            [cs.CR, cs.LG]
# 6836            [cs.CL, cs.AI]
# 7183            [cs.CL, cs.AI]
# 7227            [cs.CL, cs.AI]
# 8197            [cs.CL, cs.LG]
# 8209                   [cs.CL]
# 8448     [cs.CL, cs.IR, cs.PL]
# 10238                  [cs.CL]
# 12298    [cs.LG, cs.CL, cs.SI]
# 12732                  [cs.CL]
# 12783           [cs.CL, cs.AI]
# 16077           [cs.AI, cs.RO]
# 16175           [cs.HC, cs.AI]
# 16609    [cs.IR, cs.AI, cs.CL]
#
#                                                 abstract  \
# 1676     Significant advances have been made in recen...
# 2174     Propaganda spreads the ideology and beliefs ...
# 2175     In this paper, we assess the ability of BERT...
# 2246     In this paper, we particularly work on the c...
# 3535     Recurrent deep learning language models like...
# 3743     The conceptualization of a claim lies at the...
# 3901     Toxicity detection of text has been a popula...
# 3902     In this article, we present our methodologie...
# 3923     Establishing a good information retrieval sy...
# 3936     While there has been significant progress to...
# 4093     Opioid and substance misuse is rampant in th...
# 5576     Deep Contextual Language Models (LMs) like E...
# 5695     Alzheimers disease is a fatal progressive br...
# 5705     Long-Short-Term-Memory (LSTM) networks have ...
# 6836     In this paper, we analyze zero-shot taxonomy...
# 7183     Analyzing gender is critical to study mental...
# 7227     Online social networks are ubiquitous and us...
# 8197     Code-Mixed text data consists of sentences h...
# 8209     Knowledge Graphs are a great resource to cap...
# 8448     Representational Similarity Analysis is a me...
# 10238    This paper presents the work of restoring pu...
# 12298    Opioid and substance misuse is rampant in th...
# 12732    A legal document is usually long and dense r...
# 12783    A fundamental question in natural language p...
# 16077    Artificial Intelligence (AI) for supporting ...
# 16175    Imagine stepping into a virtual world that's...
# 16609    This paper introduces a system used to gener...
#
#                                                 versions first_category  \
# 1676   [{'version': 'v1', 'created': 'Mon, 30 Mar 202...          cs.LG
# 2174   [{'version': 'v1', 'created': 'Sun, 31 May 202...          cs.CL
# 2175   [{'version': 'v1', 'created': 'Sun, 31 May 202...          cs.CL
# 2246   [{'version': 'v1', 'created': 'Tue, 16 Jun 202...          cs.CL
# 3535   [{'version': 'v1', 'created': 'Sat, 26 Dec 202...          cs.CR
# 3743   [{'version': 'v1', 'created': 'Thu, 28 Jan 202...          cs.CL
# 3901   [{'version': 'v1', 'created': 'Wed, 24 Feb 202...          cs.CL
# 3902   [{'version': 'v1', 'created': 'Wed, 24 Feb 202...          cs.CL
# 3923   [{'version': 'v1', 'created': 'Sun, 28 Feb 202...          cs.IR
# 3936   [{'version': 'v1', 'created': 'Mon, 1 Mar 2021...          cs.CL
# 4093   [{'version': 'v1', 'created': 'Mon, 29 Mar 202...          cs.AI
# 5576   [{'version': 'v1', 'created': 'Wed, 15 Sep 202...          cs.CL
# 5695   [{'version': 'v1', 'created': 'Wed, 22 Sep 202...          cs.CL
# 5705   [{'version': 'v1', 'created': 'Thu, 23 Sep 202...          cs.CR
# 6836   [{'version': 'v1', 'created': 'Thu, 10 Feb 202...          cs.CL
# 7183   [{'version': 'v1', 'created': 'Tue, 22 Mar 202...          cs.CL
# 7227   [{'version': 'v1', 'created': 'Sun, 27 Mar 202...          cs.CL
# 8197   [{'version': 'v1', 'created': 'Fri, 17 Jun 202...          cs.CL
# 8209   [{'version': 'v1', 'created': 'Sat, 18 Jun 202...          cs.CL
# 8448   [{'version': 'v1', 'created': 'Fri, 15 Jul 202...          cs.CL
# 10238  [{'version': 'v1', 'created': 'Sat, 10 Dec 202...          cs.CL
# 12298  [{'version': 'v1', 'created': 'Thu, 20 Apr 202...          cs.LG
# 12732  [{'version': 'v1', 'created': 'Sat, 6 May 2023...          cs.CL
# 12783  [{'version': 'v1', 'created': 'Mon, 8 May 2023...          cs.CL
# 16077  [{'version': 'v1', 'created': 'Tue, 8 Aug 2023...          cs.AI
# 16175  [{'version': 'v1', 'created': 'Fri, 28 Jul 202...          cs.HC
# 16609  [{'version': 'v1', 'created': 'Wed, 16 Aug 202...          cs.IR
#
#                   v1_date                                   LM_related_terms  \
# 1676  2020-03-30 21:10:19                             [language model, BERT]
# 2174  2020-05-31 19:35:53                                             [BERT]
# 2175  2020-05-31 20:55:08                             [BERT, language model]
# 2246  2020-06-16 02:11:18                             [language model, BERT]
# 3535  2020-12-26 18:00:37                                   [language model]
# 3743  2021-01-28 09:51:30                                   [language model]
# 3901  2021-02-24 12:30:09                                             [BERT]
# 3902  2021-02-24 12:33:12                             [language model, BERT]
# 3923  2021-02-28 03:04:29                                            [XLNet]
# 3936  2021-03-01 09:07:58                             [language model, BERT]
# 4093  2021-03-29 16:58:26                                             [BERT]
# 5576  2021-09-15 08:00:33                             [language model, BERT]
# 5695  2021-09-22 19:57:04                                             [BERT]
# 5705  2021-09-23 17:03:34                                   [language model]
# 6836  2022-02-10 07:29:05                                   [language model]
# 7183  2022-03-22 16:32:51                             [language model, BERT]
# 7227  2022-03-27 10:15:34  [pretrained language model, language model, BERT]
# 8197  2022-06-17 10:36:50                                             [BERT]
# 8209  2022-06-18 18:12:20                                   [language model]
# 8448  2022-07-15 19:04:43                             [language model, BERT]
# 10238 2022-12-10 19:54:53                             [language model, BERT]
# 12298 2023-04-20 17:47:13                                             [BERT]
# 12732 2023-05-06 17:04:51                                             [BERT]
# 12783 2023-05-08 18:53:14                                   [language model]
# 16077 2023-08-08 10:35:25                                          [ChatGPT]
# 16175 2023-07-28 05:44:20                                   [GPT-3, ChatGPT]
# 16609 2023-08-16 21:20:50                                            [GPT-2]
#
#        mentions_LM_keyword                               cluster  \
# 1676                  True        Question Answering & Retrieval
# 2174                  True         Social Media & Misinformation
# 2175                  True            Emotion/Sentiment Analysis
# 2246                  True         Spelling & Grammar Correction
# 3535                  True           Privacy & Adversarial Risks
# 3743                  True                        Biases & Harms
# 3901                  True                Toxicity & Hate Speech
# 3902                  True        Question Answering & Retrieval
# 3923                  True            Entity Extraction & RecSys
# 3936                  True  Translation & Low-Resource Languages
# 4093                  True         Social Media & Misinformation
# 5576                  True        Multilingual Transfer Learning
# 5695                  True                    NLP for Healthcare
# 5705                  True           Privacy & Adversarial Risks
# 6836                  True         Prompts & In-Context Learning
# 7183                  True         Social Media & Misinformation
# 7227                  True                Toxicity & Hate Speech
# 8197                  True  Translation & Low-Resource Languages
# 8209                  True            Search, Ranking, Retrieval
# 8448                  True                       Code Generation
# 10238                 True         Spelling & Grammar Correction
# 12298                 True         Social Media & Misinformation
# 12732                 True  Legal & Scientific Document Analysis
# 12783                 True    Representations, Syntax, Semantics
# 16077                 True                    NLP for Healthcare
# 16175                 True          Applications of LLMs/ChatGPT
# 16609                 True          Human Feedback & Interaction
#
#                                                  domains  industry  academic  \
# 1676                   [bits-pilani.ac.in, igcar.gov.in]     False     False
# 2174                                 [bits-pilani.ac.in]     False     False
# 2175               [bits-pilani.ac.in, vitstudent.ac.in]     False     False
# 2246                                 [bits-pilani.ac.in]     False     False
# 3535                  [microsoft.com, bits-pilani.ac.in]      True     False
# 3743                    [bits-pilani.ac.in, iiitd.ac.in]     False      True
# 3901                       [bits-pilani.ac.in, uncg.edu]     False     False
# 3902                                 [bits-pilani.ac.in]     False     False
# 3923                                 [bits-pilani.ac.in]     False     False
# 3936               [bits-pilani.ac.in, vitstudent.ac.in]     False     False
# 4093   [mahidol.edu, ohio-state.edu, asu.edu, sc.edu,...     False      True
# 5576                   [microsft.com, bits-pilani.ac.in]     False     False
# 5695                                 [bits-pilani.ac.in]     False     False
# 5705                  [microsoft.com, bits-pilani.ac.in]      True     False
# 6836                  [bits-pilani.ac.in, cardiff.ac.uk]     False      True
# 7183   [bits-pilani.ac.in, sc.edu, ucsf.edu, iiitd.ac...     False      True
# 7227                                 [bits-pilani.ac.in]     False     False
# 8197                                 [bits-pilani.ac.in]     False     False
# 8209                         [bits-pilani.ac.in, sc.edu]     False      True
# 8448                                 [bits-pilani.ac.in]     False     False
# 10238                    [bits-pilani.ac.in, ntu.edu.sg]     False      True
# 12298  [asu.edu, sc.edu, iiitd.ac.in, mahidol.ac.th, ...     False      True
# 12732                                [bits-pilani.ac.in]     False     False
# 12783          [bits-pilani.ac.in, sc.edu, iitkgp.ac.in]     False      True
# 16077                                [bits-pilani.ac.in]     False     False
# 16175  [kiit.ac.in, ntu.edu.sg, uky.edu, napier.ac.uk...     False      True
# 16609  [bits-pilani.ac.in, um.edu.mt, togelius.com, n...     False      True
#
#       above_pred_female_threshold  \
# 1676                        False
# 2174                         True
# 2175                        False
# 2246                        False
# 3535                        False
# 3743                         True
# 3901                        False
# 3902                        False
# 3923                        False
# 3936                        False
# 4093                        False
# 5576                         True
# 5695                        False
# 5705                        False
# 6836                        False
# 7183                        False
# 7227                         True
# 8197                        False
# 8209                        False
# 8448                         True
# 10238                       False
# 12298                        True
# 12732                        True
# 12783                       False
# 16077                       False
# 16175                       False
# 16609                       False
#
#        inferred_female_frac_nqg_uncertainty_threshold_0.100  citationCount  \
# 1676                                            0.000000               7.0
# 2174                                            0.500000               8.0
# 2175                                            0.000000               5.0
# 2246                                            0.000000               2.0
# 3535                                            0.000000               4.0
# 3743                                            0.500000               9.0
# 3901                                            0.000000               9.0
# 3902                                            0.000000               2.0
# 3923                                            0.000000               2.0
# 3936                                            0.250000               1.0
# 4093                                            0.333333               6.0
# 5576                                            0.600000               3.0
# 5695                                            0.000000               4.0
# 5705                                            0.000000               0.0
# 6836                                            0.000000               4.0
# 7183                                            0.333333               6.0
# 7227                                            0.500000               8.0
# 8197                                            0.000000               1.0
# 8209                                            0.000000               1.0
# 8448                                            0.500000               0.0
# 10238                                           0.000000               0.0
# 12298                                           0.500000               2.0
# 12732                                           0.500000               0.0
# 12783                                           0.000000               5.0
# 16077                                           0.000000               0.0
# 16175                                           0.000000               0.0
# 16609                                           0.000000               0.0
#
#        percentile_rank_in_3_month_window  percentile_rank_in_12_month_window
# 1676                            0.242000                            0.314909
# 2174                            0.276190                            0.345332
# 2175                            0.184127                            0.245936
# 2246                            0.088095                            0.116117
# 3535                            0.236196                            0.207850
# 3743                            0.446023                            0.526070
# 3901                            0.446023                            0.526070
# 3902                            0.140152                            0.189171
# 3923                            0.140152                            0.189171
# 3936                            0.089015                            0.119151
# 4093                            0.334280                            0.415775
# 5576                            0.246883                            0.254846
# 5695                            0.314214                            0.315007
# 5705                            0.041147                            0.041110
# 6836                            0.386648                            0.534366
# 7183                            0.474270                            0.627392
# 7227                            0.545202                            0.692724
# 8197                            0.188462                            0.249245
# 8209                            0.188462                            0.249245
# 8448                            0.103164                            0.088746
# 10238                           0.116420                            0.088746
# 12298                           0.652147                            0.684845
# 12732                           0.199259                            0.228022
# 12783                           0.831480                            0.841139
# 16077                           0.353985                            0.228022
# 16175                           0.353985                            0.228022
# 16609                           0.353985                            0.228022

# %%
domain_counts_v2['u-tokyo.ac'], domain_counts['u-tokyo.ac']
# Out:
# (48, 48)

# %% [markdown]
# ### Load annotated data

# %%
lm_metadata = utils.load_annotated_lm_metadata()
display(lm_metadata.sample(5))

lm_metadata['n_authors'] = lm_metadata.authors.apply(lambda x: len(x))
# Out:
#                      id                                            authors  \
# 15402  arXiv:2307.06540                       [Yufei Xie, Rodolfo C. Raga]
# 11070  arXiv:2302.07445  [Jiamou Sun, Zhenchang Xing, Qinghua Lu, Xiwei...
# 4378   arXiv:2104.10640                     [Sushant Singh, Ausif Mahmood]
# 3869   arXiv:2102.09914  [Brooke Stephenson, Thomas Hueber, Laurent Gir...
# 9373   arXiv:2210.09549  [Ruijun Li, Weihua Li, Yi Yang, Hanyu Wei, Jia...
#
#                                                    title        categories  \
# 15402  Convolutional Neural Networks for Sentiment An...    [cs.CL, cs.LG]
# 11070  Silent Vulnerable Dependency Alert Prediction ...    [cs.CR, cs.SE]
# 4378   The NLP Cookbook: Modern Recipes for Transform...    [cs.CL, cs.LG]
# 3869   Alternate Endings: Improving Prosody for Incre...  [cs.CL, eess.AS]
# 9373   Swinv2-Imagen: Hierarchical Vision Transformer...    [cs.CV, cs.LG]
#
#                                                 abstract  \
# 15402    This study addressed the complex task of sen...
# 11070    Due to convenience, open-source software is ...
# 4378     In recent years, Natural Language Processing...
# 3869     The prosody of a spoken word is determined b...
# 9373     Recently, diffusion models have been proven ...
#
#                                                 versions first_category  \
# 15402  [{'version': 'v1', 'created': 'Thu, 13 Jul 202...          cs.CL
# 11070  [{'version': 'v1', 'created': 'Wed, 15 Feb 202...          cs.CR
# 4378   [{'version': 'v1', 'created': 'Tue, 23 Mar 202...          cs.CL
# 3869   [{'version': 'v1', 'created': 'Fri, 19 Feb 202...          cs.CL
# 9373   [{'version': 'v1', 'created': 'Tue, 18 Oct 202...          cs.CV
#
#                   v1_date        LM_related_terms  mentions_LM_keyword  \
# 15402 2023-07-13 03:02:56                  [BERT]                 True
# 11070 2023-02-15 03:32:03                  [BERT]                 True
# 4378  2021-03-23 22:38:20  [language model, BERT]                 True
# 3869  2021-02-19 13:11:34        [language model]                 True
# 9373  2022-10-18 02:50:34        [language model]                 True
#
#                            cluster  \
# 15402   Emotion/Sentiment Analysis
# 11070  Privacy & Adversarial Risks
# 4378      Efficiency & Performance
# 3869            Speech Recognition
# 9373     Video & Multimodal Models
#
#                                                  domains  industry  academic  \
# 15402    [students.national-u.edu.ph, national-u.edu.ph]     False     False
# 11070                             [csiro.au, anu.edu.au]     False      True
# 4378                                 [my.bridgeport.edu]     False     False
# 3869   [univ-grenoble-alpes.fr, gipsa-lab.grenoble-in...     False      True
# 9373   [autuni.ac.nz, jlufe.edu.cn, utas.edu.au, aut....     False     False
#
#       above_pred_female_threshold  \
# 15402                       False
# 11070                       False
# 4378                        False
# 3869                        False
# 9373                          NaN
#
#        inferred_female_frac_nqg_uncertainty_threshold_0.100  citationCount  \
# 15402                                               0.00               0.0
# 11070                                               0.00               1.0
# 4378                                                0.00              37.0
# 3869                                                0.25              10.0
# 9373                                                 NaN               4.0
#
#        percentile_rank_in_3_month_window  percentile_rank_in_12_month_window
# 15402                           0.353985                            0.228022
# 11070                           0.340574                            0.546834
# 4378                            0.808712                            0.852941
# 3869                            0.473485                            0.556150
# 9373                            0.639973                            0.534366

# %% [markdown]
# ## Proportion of papers with different authorship groups: pre-2023 v. 2023

# %%
lm_metadata_pre_2023 = lm_metadata[lm_metadata['v1_date'] < RECENT_DATE_THRESHOLD]
lm_metadata_post_2023 = lm_metadata[lm_metadata['v1_date'] >= RECENT_DATE_THRESHOLD]

# %% [markdown]
# ### Affiliation

# %%
# # This sets the denominator as any paper with at least one tracked domain (deprecated)
# papers_with_domain_pre_2023 = lm_metadata_pre_2023.domains.apply(lambda x: len(x) > 0).sum()
# papers_with_domain_post_2023 = lm_metadata_post_2023.domains.apply(lambda x: len(x) > 0).sum()

# This sets the denominator as any paper from one of the institutions with >= 10 papers
papers_with_domain_pre_2023 = lm_metadata_pre_2023.apply(lambda x: x.academic or x.industry, axis=1).sum()
papers_with_domain_post_2023 = lm_metadata_post_2023.apply(lambda x: x.academic or x.industry, axis=1).sum()

# Academic
n_acad_pre_2023 = lm_metadata_pre_2023['academic'].sum()
print(f'Academic pre-2023: {n_acad_pre_2023} out of {papers_with_domain_pre_2023} ({100*n_acad_pre_2023/papers_with_domain_pre_2023 :.1f}%)')
n_acad_post_2023 = lm_metadata_post_2023['academic'].sum()
print(f'Academic post-2023: {n_acad_post_2023} out of {papers_with_domain_post_2023} ({100*n_acad_post_2023/papers_with_domain_post_2023 :.1f}%)')
print()

# Industry
n_ind_pre_2023 = lm_metadata_pre_2023['industry'].sum()
print(f'Industry pre-2023: {n_ind_pre_2023} out of {papers_with_domain_pre_2023} ({100*n_ind_pre_2023/papers_with_domain_pre_2023 :.1f}%)')
n_ind_post_2023 = lm_metadata_post_2023['industry'].sum()
print(f'Industry post-2023: {n_ind_post_2023} out of {papers_with_domain_post_2023} ({100*n_ind_post_2023/papers_with_domain_post_2023 :.1f}%)')
# Out:
# Academic pre-2023: 6153 out of 7372 (83.5%)
# Academic post-2023: 3784 out of 4255 (88.9%)
#
# Industry pre-2023: 2642 out of 7372 (35.8%)
# Industry post-2023: 1132 out of 4255 (26.6%)

# %%
# Count the % papers in the top 10 US domains before and after 2023: utils.top_10_us_institution_domains
# Count the % papers in the top 10 Chinese domains before and after 2023: utils.top_10_chinese_institution_domains

# Top 10 US
n_us_pre_2023 = lm_metadata_pre_2023.domains.apply(lambda x: len(set(x).intersection(utils.top_10_us_institution_domains)) > 0).sum()
print(f'US pre-2023: {n_us_pre_2023} out of {papers_with_domain_pre_2023} ({100*n_us_pre_2023/papers_with_domain_pre_2023 :.1f}%)')
n_us_post_2023 = lm_metadata_post_2023.domains.apply(lambda x: len(set(x).intersection(utils.top_10_us_institution_domains)) > 0).sum()
print(f'US post-2023: {n_us_post_2023} out of {papers_with_domain_post_2023} ({100*n_us_post_2023/papers_with_domain_post_2023 :.1f}%)')
print()

# Top 10 China
n_china_pre_2023 = lm_metadata_pre_2023.domains.apply(lambda x: len(set(x).intersection(utils.top_10_chinese_institution_domains)) > 0).sum()
print(f'China pre-2023: {n_china_pre_2023} out of {papers_with_domain_pre_2023} ({100*n_china_pre_2023/papers_with_domain_pre_2023 :.1f}%)')
n_china_post_2023 = lm_metadata_post_2023.domains.apply(lambda x: len(set(x).intersection(utils.top_10_chinese_institution_domains)) > 0).sum()
print(f'China post-2023: {n_china_post_2023} out of {papers_with_domain_post_2023} ({100*n_china_post_2023/papers_with_domain_post_2023 :.1f}%)')

# Do Chi-square tests for increase in US papers from pre-2023 to post-2023, same for China
from scipy.stats import chi2_contingency
print()
print("Significant increase in top 10 U.S. university papers?")
print(chi2_contingency([[n_us_pre_2023, n_us_post_2023], [papers_with_domain_pre_2023 - n_us_pre_2023, papers_with_domain_post_2023 - n_us_post_2023]]))

print()
print("Significant increase in top 10 Chinese university papers?")
print(chi2_contingency([[n_china_pre_2023, n_china_post_2023], [papers_with_domain_pre_2023 - n_china_pre_2023, papers_with_domain_post_2023 - n_china_post_2023]]))
# Out:
# US pre-2023: 1289 out of 7372 (17.5%)
# US post-2023: 715 out of 4255 (16.8%)
#
# China pre-2023: 935 out of 7372 (12.7%)
# China post-2023: 687 out of 4255 (16.1%)
#
# Significant increase in top 10 U.S. university papers?
# Chi2ContingencyResult(statistic=0.8307872522569287, pvalue=0.36204498556760867, dof=1, expected_freq=array([[1270.61907629,  733.38092371],
#        [6101.38092371, 3521.61907629]]))
#
# Significant increase in top 10 Chinese university papers?
# Chi2ContingencyResult(statistic=26.657786980984238, pvalue=2.4286999226553046e-07, dof=1, expected_freq=array([[1028.41524039,  593.58475961],
#        [6343.58475961, 3661.41524039]]))

# %% [markdown]
# ### Pred. gender

# %%
# This is the number of papers with at least one predicted gender for one of the authors.
papers_with_pred_gender_pre_2023 = (~pd.isna(lm_metadata_pre_2023.above_pred_female_threshold)).sum()
papers_with_pred_gender_post_2023 = (~pd.isna(lm_metadata_post_2023.above_pred_female_threshold)).sum()

# Majority predicted-female
n_pred_female_pre_2023 = lm_metadata_pre_2023['above_pred_female_threshold'].sum()
print(f'Majority predicted-female pre-2023: {n_pred_female_pre_2023} out of {papers_with_pred_gender_pre_2023} ({100*n_pred_female_pre_2023/papers_with_pred_gender_pre_2023 :.1f}%)')
n_pred_female_post_2023 = lm_metadata_post_2023['above_pred_female_threshold'].sum()
print(f'Majority predicted-female post-2023: {n_pred_female_post_2023} out of {papers_with_pred_gender_post_2023} ({100*n_pred_female_post_2023/papers_with_pred_gender_post_2023 :.1f}%)')
# Out:
# Majority predicted-female pre-2023: 1712.0 out of 9769 (17.5%)
# Majority predicted-female post-2023: 946.0 out of 5886 (16.1%)

# %% [markdown]
# ### Predicted gender vs. industry/academic

# %%
papers_with_gender = lm_metadata[(~pd.isna(lm_metadata.above_pred_female_threshold))]
n_total = len(papers_with_gender)

# Compute above_pred_female_threshold for academic and industry papers separately
n_pred_female_industry = ((papers_with_gender.above_pred_female_threshold) & (papers_with_gender.industry)).sum()
n_industry = (papers_with_gender.industry).sum()
print(f'Majority pred-female on industry-affiliated papers: {n_pred_female_industry} out of {n_industry} papers ({100*n_pred_female_industry/n_industry :.1f}%)')

n_pred_female_industry_only = ((papers_with_gender.above_pred_female_threshold) & (papers_with_gender.industry) & (~papers_with_gender.academic)).sum()
n_industry_only = ((papers_with_gender.industry) & (~papers_with_gender.academic)).sum()
print(f'Majority pred-female on industry-affiliation-only papers: {n_pred_female_industry_only} out of {n_industry_only} papers ({100*n_pred_female_industry_only/n_industry_only :.1f}%)')

n_pred_female_academic = ((papers_with_gender.above_pred_female_threshold) & (papers_with_gender.academic)).sum()
n_academic = (papers_with_gender.academic).sum()
print(f'Majority pred-female on academic-affiliated papers: {n_pred_female_academic} out of {n_academic} papers ({100*n_pred_female_academic/n_academic :.1f}%)')

n_pred_female_academic_only = ((papers_with_gender.above_pred_female_threshold) & (~papers_with_gender.industry) & (papers_with_gender.academic)).sum()
n_academic_only = ((~papers_with_gender.industry) & (papers_with_gender.academic)).sum()
print(f'Majority pred-female on academic-affiliation-only papers: {n_pred_female_academic_only} out of {n_academic_only} papers ({100*n_pred_female_academic_only/n_academic_only :.1f}%)')

n_pred_female_collab = ((papers_with_gender.above_pred_female_threshold) & (papers_with_gender.industry) & (papers_with_gender.academic)).sum()
n_collab = ((papers_with_gender.industry) & (papers_with_gender.academic)).sum()
print(f'Majority pred-female on industry & academic-affiliated papers: {n_pred_female_collab} out of {n_collab} papers ({100*n_pred_female_collab/n_collab :.1f}%)')

print(chi2_contingency([[n_pred_female_industry_only, n_industry_only],
                        [n_pred_female_academic_only, n_academic_only]]))
# Out:
# Majority pred-female on industry-affiliated papers: 472 out of 3520 papers (13.4%)
# Majority pred-female on industry-affiliation-only papers: 191 out of 1592 papers (12.0%)
# Majority pred-female on academic-affiliated papers: 1648 out of 9095 papers (18.1%)
# Majority pred-female on academic-affiliation-only papers: 1367 out of 7167 papers (19.1%)
# Majority pred-female on industry & academic-affiliated papers: 281 out of 1928 papers (14.6%)
# Chi2ContingencyResult(statistic=31.974369384949345, pvalue=1.5622022722865024e-08, dof=1, expected_freq=array([[ 269.25598527, 1513.74401473],
#        [1288.74401473, 7245.25598527]]))

# %% [markdown]
# ### Author count

# %%
# Map author counts to 1, 2-5, 6-9, or 10+
def map_author_counts(x):
    if x == 1: return '1'
    elif x <= 5: return '2-5'
    elif x <= 9: return '6-9'
    else: return '10+'

# Paper team size percentages sorted by keys
print('Pre-2023 paper team sizes')
print('Mean team size:', lm_metadata_pre_2023.n_authors.median())
print(lm_metadata_pre_2023.n_authors.apply(map_author_counts).value_counts().sort_index())
print(lm_metadata_pre_2023.n_authors.apply(map_author_counts).value_counts().sort_index() / len(lm_metadata_pre_2023))

print('Post-2023 paper team sizes')
print('Mean team size:', lm_metadata_post_2023.n_authors.median())
print(lm_metadata_post_2023.n_authors.apply(map_author_counts).value_counts().sort_index())
print(lm_metadata_post_2023.n_authors.apply(map_author_counts).value_counts().sort_index() / len(lm_metadata_post_2023))
# Out:
# Pre-2023 paper team sizes
# Mean team size: 4.0
# 1       364
# 10+     436
# 2-5    7346
# 6-9    2406
# Name: n_authors, dtype: int64
# 1      0.034496
# 10+    0.041319
# 2-5    0.696171
# 6-9    0.228014
# Name: n_authors, dtype: float64
# Post-2023 paper team sizes
# Mean team size: 5.0
# 1       323
# 10+     513
# 2-5    3790
# 6-9    1801
# Name: n_authors, dtype: int64
# 1      0.050257
# 10+    0.079820
# 2-5    0.589700
# 6-9    0.280224
# Name: n_authors, dtype: float64

# %%
# Compute chi2 test on the frequency of solo-author papers

print(chi2_contingency([[lm_metadata_pre_2023.n_authors.apply(lambda x: x == 1).sum(),
                            lm_metadata_post_2023.n_authors.apply(lambda x: x == 1).sum()],
                        [lm_metadata_pre_2023.n_authors.apply(lambda x: x > 1).sum(),
                            lm_metadata_post_2023.n_authors.apply(lambda x: x > 1).sum()]]))
# Out:
# Chi2ContingencyResult(statistic=25.151258126479604, pvalue=5.300506209523394e-07, dof=1, expected_freq=array([[  426.95235291,   260.04764709],
#        [10125.04764709,  6166.95235291]]))
