# %% [markdown]
# # Preprocess metadata
#
# In this script, we'll start with the full, unprocessed metadata JSON downloaded directly from Kaggle.
# Cleaning:
# - Parse some of the columns to include useful info (v1_date, first_category, etc.)
# - Drop unnecessary columns
# - Parse author name lists to be a list of Firstname {Middle} Lastname.
#
# Subsetting:
# - Only include papers since 2018
# - Only include papers with at least one 'cs' or 'stat' category
#
# LLM annotation:
# - Annotate papers based on whether they contain an LLM-related keyword ('mentions_LM_keyword'); include all such keywords in a list column
# - Create an ```lm_metadata``` sub-dataframe of LLM papers with mentions_LM_keyword == True, so that we can use this for downstream things (extracting S2 info, getting fulltexts, etc)
#
# (Optional) Use paper fulltexts to extract affiliations for the LLM papers. These data are necessary for the analyses involving affiliations.
# - *Outside of this notebook:* Download fulltext PDFs from Google Cloud. You can't restrict to only a certain subset of papers, so you'll need to download all papers, but you can start at 2018. e.g. ```gsutil -m cp -r gs://arxiv-dataset/arxiv/arxiv/pdf/18* /path/to/output``` will download only 2018 papers and you can use analogous commands for 2019-present.
# - For the LLM papers, convert PDFs to fulltext using the pdftotext tool (code is in the notebook).
# - Parse each paper's converted .txt file to look for email addresses to infer affiliation. Store emails in the metadata dataframe.
#
# Output:
# - Output the processed overall metadata df and the LLM-specific metadata df as JSON files to '/share/pierson/raj/LLM_bibliometrics_v2/processed_data/'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime
from tqdm import tqdm
import os
import sys

if '/home/rm868/LLM-publication-patterns/data_prep' not in sys.path:
    sys.path.append('/home/rm868/LLM-publication-patterns/data_prep')

from preprocess_utils import BASE_DATA_DIR, PROCESSED_DATA_DIR
from preprocess_utils import get_lm_terms

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Load + clean columns

# %%
# Takes about 1m30s to load all metadata
metadata_date = '20230910'
metadata_path = os.path.join(BASE_DATA_DIR, f'{metadata_date}-arxiv-metadata-oai-snapshot.json')
metadata = pd.read_json(metadata_path, lines=True)

# %%
metadata.sample(5)
# Out:
#                      id                submitter  \
# 800237       1612.04428            David Renfrew
# 924574       1712.05975  Pablo Portilla Cuadrado
# 1484853      2106.07089            Luca Cardelli
# 2129115  hep-ph/0410225         Terunuma Sachiko
# 908557       1711.01547          Daniel Rohrlich
#
#                                                    authors  \
# 800237   Nicholas A. Cook, Walid Hachem, Jamal Najim an...
# 924574                             Pablo Portilla Cuadrado
# 1484853    Luca Cardelli, Marta Kwiatkowska, Luca Laurenti
# 2129115        M. Bando, T. Kugo, A. Sugamoto, S. Terunuma
# 908557                  Agung Budiyono and Daniel Rohrlich
#
#                                                      title  \
# 800237   Non-Hermitian random matrices with a variance ...
# 924574   General t\^ete-\`a-t\^ete graphs and Seifert m...
# 1484853  A Language for Modeling And Optimizing Experim...
# 2129115  Pentaquark Baryons in String Theory -- Talk at...
# 908557   Quantum mechanics as classical statistical mec...
#
#                                                   comments  \
# 800237   50 pages. The original arXiv submission has be...
# 924574   22 pages, 20 figures. arXiv admin note: text o...
# 1484853                                               None
# 2129115  talk given by A. Sugamoto at International Wor...
# 908557                          12 pages; comments welcome
#
#                                   journal-ref                         doi  \
# 800237                                   None           10.1214/18-EJP230
# 924574                                   None                        None
# 1484853                                  None                        None
# 2129115                                  None                        None
# 908557   Nature Communications 8, 1306 (2017)  10.1038/s41467-017-01375-w
#
#         report-no       categories  \
# 800237       None          math.PR
# 924574       None  math.GT math.GN
# 1484853      None         q-bio.QM
# 2129115      None           hep-ph
# 908557       None         quant-ph
#
#                                                    license  \
# 800237   http://arxiv.org/licenses/nonexclusive-distrib...
# 924574   http://arxiv.org/licenses/nonexclusive-distrib...
# 1484853        http://creativecommons.org/licenses/by/4.0/
# 2129115                                               None
# 908557   http://arxiv.org/licenses/nonexclusive-distrib...
#
#                                                   abstract  \
# 800237     For each $n$, let $A_n=(\sigma_{ij})$ be an ...
# 924574     T\^ete-\`a-t\^ete graphs and relative t\^ete...
# 1484853    Automation is becoming ubiquitous in all lab...
# 2129115    Pentaquark baryons $\Theta^{+}$ and $\Xi^{--...
# 908557     Where does quantum mechanics part ways with ...
#
#                                                   versions update_date  \
# 800237   [{'version': 'v1', 'created': 'Tue, 13 Dec 201...  2020-08-03
# 924574   [{'version': 'v1', 'created': 'Sat, 16 Dec 201...  2017-12-19
# 1484853  [{'version': 'v1', 'created': 'Sun, 13 Jun 202...  2021-11-30
# 2129115  [{'version': 'v1', 'created': 'Fri, 15 Oct 200...  2007-05-23
# 908557   [{'version': 'v1', 'created': 'Sun, 5 Nov 2017...  2017-11-07
#
#                                             authors_parsed
# 800237   [[Cook, Nicholas A., ], [Hachem, Walid, ], [Na...
# 924574                      [[Cuadrado, Pablo Portilla, ]]
# 1484853  [[Cardelli, Luca, ], [Kwiatkowska, Marta, ], [...
# 2129115  [[Bando, M., ], [Kugo, T., ], [Sugamoto, A., ]...
# 908557         [[Budiyono, Agung, ], [Rohrlich, Daniel, ]]

# %%
metadata['categories'] = metadata['categories'].apply(lambda x: x.split(' '))
metadata['first_category'] = metadata['categories'].apply(lambda x: x[0])
metadata['authors'] = metadata['authors_parsed']
metadata['v1_date'] = metadata['versions'].apply(lambda x: x[0]['created'])
metadata['v1_date'] = pd.to_datetime(metadata['v1_date'], format='%a, %d %b %Y %H:%M:%S GMT')
metadata = metadata.drop(['submitter', 'update_date', 'authors_parsed', 'comments', 'journal-ref', 'doi', 'report-no', 'license'], axis=1)
display(metadata.sample(5))
# Out:
#                        id                                            authors  \
# 851178         1705.07637  [[Bordalba, Ricard, ], [Ros, Lluís, ], [Porta,...
# 1738359        2210.17004  [[Liu, Aiwei, ], [Yu, Honghai, ], [Hu, Xuming,...
# 1993870  cond-mat/0009148  [[Kezsmarki, I., ], [Csonka, Sz., ], [Berger, ...
# 1497429        2107.03417  [[Kukavica, Igor, ], [Nguyen, Trinh, ], [Vicol...
# 1754283        2211.15377  [[Carneiro, Hugo, ], [Weber, Cornelius, ], [We...
#
#                                                      title  \
# 851178        Kinodynamic Planning on Constraint Manifolds
# 1738359  Character-level White-Box Adversarial Attacks ...
# 1993870      Pressure dependence of the spin gap in BaVS_3
# 1497429  On the Euler+Prandtl expansion for the Navier-...
# 1754283  Whose Emotion Matters? Speaking Activity Local...
#
#                                     categories  \
# 851178                                 [cs.RO]
# 1738359                                [cs.CL]
# 1993870   [cond-mat.str-el, cond-mat.mtrl-sci]
# 1497429                              [math.AP]
# 1754283  [eess.AS, cs.CV, cs.LG, cs.NE, cs.SD]
#
#                                                   abstract  \
# 851178     This paper presents a motion planner for sys...
# 1738359    We propose the first character-level white-b...
# 1993870    We carried out magnetotransport experiments ...
# 1497429    We establish the validity of the Euler$+$Pra...
# 1754283    The task of emotion recognition in conversat...
#
#                                                   versions   first_category  \
# 851178   [{'version': 'v1', 'created': 'Mon, 22 May 201...            cs.RO
# 1738359  [{'version': 'v1', 'created': 'Mon, 31 Oct 202...            cs.CL
# 1993870  [{'version': 'v1', 'created': 'Mon, 11 Sep 200...  cond-mat.str-el
# 1497429  [{'version': 'v1', 'created': 'Wed, 7 Jul 2021...          math.AP
# 1754283  [{'version': 'v1', 'created': 'Wed, 23 Nov 202...          eess.AS
#
#                     v1_date
# 851178  2017-05-22 09:59:09
# 1738359 2022-10-31 01:46:29
# 1993870 2000-09-11 12:15:24
# 1497429 2021-07-07 18:03:56
# 1754283 2022-11-23 09:57:17

# %% [markdown]
# ### Subset + fix author names

# %%
# Subset the dataframe, including papers only that:
# - Were posted since 2018-01-01
# - Have at least one category which startswith 'cs.' or 'stat.'

# metadata = metadata[metadata['v1_date'] >= datetime(2018, 1, 1, 0, 0, 0)]
# metadata = metadata[metadata['v1_date'] >= datetime(2008, 1, 1, 0, 0, 0)]
metadata = metadata[metadata['categories'].apply(lambda x: any([c.startswith('cs.') or c.startswith('stat.') for c in x]))]

display(metadata)
# Out:
#                        id                                            authors  \
# 1               0704.0002           [[Streinu, Ileana, ], [Theran, Louis, ]]
# 45              0704.0046      [[Csiszar, I., ], [Hiai, F., ], [Petz, D., ]]
# 46              0704.0047                    [[Kosel, T., ], [Grabec, I., ]]
# 49              0704.0050                    [[Kosel, T., ], [Grabec, I., ]]
# 61              0704.0062  [[Šrámek, Rastislav, ], [Brejová, Broňa, ], [V...
# ...                   ...                                                ...
# 2321538  quant-ph/9909094                  [[Knill, E., ], [Laflamme, R., ]]
# 2321571  quant-ph/9910033  [[Hemaspaandra, Edith, , RIT], [Hemaspaandra, ...
# 2321625  quant-ph/9910087  [[Kent, Adrian, , DAMTP, University of Cambrid...
# 2321706  quant-ph/9911043  [[Hardy, Lucien, , The Perimeter Institute], [...
# 2321887  quant-ph/9912100        [[Ohya, Masanori, ], [Volovich, Igor V., ]]
#
#                                                      title  \
# 1                 Sparsity-certifying Graph Decompositions
# 45       A limit relation for entropy and channel capac...
# 46       Intelligent location of simultaneously active ...
# 49       Intelligent location of simultaneously active ...
# 61       On-line Viterbi Algorithm and Its Relationship...
# ...                                                    ...
# 2321538  Quantum Computation and Quadratically Signed W...
# 2321571  Almost-Everywhere Superiority for Quantum Comp...
# 2321625  Unconditionally Secure Commitment of a Certifi...
# 2321706             Cheat Sensitive Quantum Bit Commitment
# 2321887  Quantum Computing, NP-complete Problems and Ch...
#
#                                                 categories  \
# 1                                         [math.CO, cs.CG]
# 45                              [quant-ph, cs.IT, math.IT]
# 46                                          [cs.NE, cs.AI]
# 49                                          [cs.NE, cs.AI]
# 61                                                 [cs.DS]
# ...                                                    ...
# 2321538                                  [quant-ph, cs.CC]
# 2321571                                  [quant-ph, cs.CC]
# 2321625                                  [quant-ph, cs.CR]
# 2321706                                  [quant-ph, cs.CR]
# 2321887  [quant-ph, chao-dyn, cond-mat.mes-hall, cs.CC,...
#
#                                                   abstract  \
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 45         In a quantum mechanical model, Diosi, Feldma...
# 46         The intelligent acoustic emission locator is...
# 49         Part I describes an intelligent acoustic emi...
# 61         In this paper, we introduce the on-line Vite...
# ...                                                    ...
# 2321538    We prove that quantum computation is polynom...
# 2321571    Simon as extended by Brassard and H{\o}yer s...
# 2321625    In a secure bit commitment protocol involvin...
# 2321706    We define cheat sensitive cryptographic prot...
# 2321887    An approach to the solution of NP-complete p...
#
#                                                   versions first_category  \
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...        math.CO
# 45       [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...       quant-ph
# 46       [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...          cs.NE
# 49       [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...          cs.NE
# 61       [{'version': 'v1', 'created': 'Sat, 31 Mar 200...          cs.DS
# ...                                                    ...            ...
# 2321538  [{'version': 'v1', 'created': 'Thu, 30 Sep 199...       quant-ph
# 2321571  [{'version': 'v1', 'created': 'Fri, 8 Oct 1999...       quant-ph
# 2321625  [{'version': 'v1', 'created': 'Wed, 20 Oct 199...       quant-ph
# 2321706  [{'version': 'v1', 'created': 'Tue, 9 Nov 1999...       quant-ph
# 2321887  [{'version': 'v1', 'created': 'Tue, 21 Dec 199...       quant-ph
#
#                     v1_date
# 1       2007-03-31 02:26:18
# 45      2007-04-01 16:37:36
# 46      2007-04-01 13:06:50
# 49      2007-04-01 18:53:13
# 61      2007-03-31 23:52:33
# ...                     ...
# 2321538 1999-09-30 22:24:33
# 2321571 1999-10-08 03:48:56
# 2321625 1999-10-20 21:09:56
# 2321706 1999-11-09 22:53:16
# 2321887 1999-12-21 22:03:01
#
# [595539 rows x 8 columns]

# %%
from preprocess_utils import fix_author_name_list

metadata['authors'] = metadata['authors'].apply(fix_author_name_list)

# %% [markdown]
# ### Annotate whether LLM paper

# %%
# Add column for list of LLM terms in title or abstract
metadata['LM_related_terms'] = metadata['title'].apply(get_lm_terms) + metadata['abstract'].apply(get_lm_terms)

# Remove duplicate entries, i.e. apply list(set()) to each list
metadata['LM_related_terms'] = metadata['LM_related_terms'].apply(lambda x: list(set(x)))
metadata['mentions_LM_keyword'] = metadata['LM_related_terms'].apply(lambda x: len(x) > 0)

# %%
lm_metadata = metadata[metadata['mentions_LM_keyword']].copy()
display(lm_metadata.sample(5), lm_metadata.shape)
# Out:
#                  id                                            authors  \
# 1530334  2109.07513  [Rami Botros, Tara N. Sainath, Robert David, E...
# 760927   1608.04465  [Ehsan Shareghi, Matthias Petri, Gholamreza Ha...
# 1202423  1911.03829  [Yen-Chun Chen, Zhe Gan, Yu Cheng, Jingzhou Li...
# 1822533  2304.04487  [Nan Yang, Tao Ge, Liang Wang, Binxing Jiao, D...
# 1792674  2302.07740  [Wei-Wei Du, Hong-Wei Wu, Wei-Yao Wang, Wen-Ch...
#
#                                                      title  \
# 1530334                       Tied & Reduced RNN-T Decoder
# 760927   Fast, Small and Exact: Infinite-order Language...
# 1202423  Distilling Knowledge Learned in BERT for Text ...
# 1822533  Inference with Reference: Lossless Acceleratio...
# 1792674  Team Triple-Check at Factify 2: Parameter-Effi...
#
#                              categories  \
# 1530334  [cs.CL, cs.LG, cs.SD, eess.AS]
# 760927                          [cs.CL]
# 1202423                  [cs.CL, cs.LG]
# 1822533                  [cs.CL, cs.AI]
# 1792674    [cs.CL, cs.AI, cs.CV, cs.LG]
#
#                                                   abstract  \
# 1530334    Previous works on the Recurrent Neural Netwo...
# 760927     Efficient methods for storing and querying a...
# 1202423    Large-scale pre-trained language model such ...
# 1822533    We propose LLMA, an LLM accelerator to lossl...
# 1792674    Multi-modal fact verification has become an ...
#
#                                                   versions first_category  \
# 1530334  [{'version': 'v1', 'created': 'Wed, 15 Sep 202...          cs.CL
# 760927   [{'version': 'v1', 'created': 'Tue, 16 Aug 201...          cs.CL
# 1202423  [{'version': 'v1', 'created': 'Sun, 10 Nov 201...          cs.CL
# 1822533  [{'version': 'v1', 'created': 'Mon, 10 Apr 202...          cs.CL
# 1792674  [{'version': 'v1', 'created': 'Sun, 12 Feb 202...          cs.CL
#
#                     v1_date                        LM_related_terms  \
# 1530334 2021-09-15 18:19:16                        [language model]
# 760927  2016-08-16 02:33:21                        [language model]
# 1202423 2019-11-10 02:12:38                  [language model, BERT]
# 1822533 2023-04-10 09:55:14  [language model, large language model]
# 1792674 2023-02-12 18:08:54                      [foundation model]
#
#          mentions_LM_keyword
# 1530334                 True
# 760927                  True
# 1202423                 True
# 1822533                 True
# 1792674                 True
# (17651, 10)

# %% [markdown]
# ## Get emails from fulltexts to determine affiliations

# %% [markdown]
# ### Convert downloaded PDFs to fulltexts
#
# Paper PDF fulltexts needed to be downloaded from GCP before running.
# These cells only need to be run once to get parsed .txt files for each paper.

# %%
from preprocess_utils import get_paper_filenames

# Create a list of filenames in the correct format for all the papers in lm_metadata
paper_filenames = lm_metadata.apply(get_paper_filenames, axis=1)
print(paper_filenames[:5])

# %%
from preprocess_utils import PAPER_PDF_DIR
LLM_FULLTEXT_DIR = os.path.join(BASE_DATA_DIR, 'llm_paper_fulltexts')

# Make all the monthyear subdirs in the destination directory
all_monthyears = lm_metadata['id'].apply(lambda x: x.split('.')[0]).unique()
for monthyear in all_monthyears:
    os.makedirs(f'{LLM_FULLTEXT_DIR}/{monthyear}', exist_ok=True)

# Create a list of PDF and text file paths
pdf_paths = []
txt_paths = []

# Populate the PDF and text file paths based on your logic
for filename, monthyear in paper_filenames:
    pdf_paths.append(f'{PAPER_PDF_DIR}/{monthyear}/{filename}.pdf')
    txt_paths.append(f'{LLM_FULLTEXT_DIR}/{monthyear}/{filename}.txt')

# %%
from preprocess_utils import convert_pdfs_in_parallel

# Call the function to convert PDFs to text
# This took 18 minutes, but may take longer with fewer threads
convert_pdfs_in_parallel(pdf_paths, txt_paths)

print("All LLM paper PDFs converted to txt files.")

# %% [markdown]
# ### Extract emails from fulltexts

# %%
# %load_ext autoreload
# %autoreload 2
from preprocess_utils import get_all_emails

fulltext_dir = os.path.join(BASE_DATA_DIR, 'llm_paper_fulltexts')

# Add emails as a column by applying the get_all_emails function to the dataframe (it takes in rows)
n_lines_to_check = 100
lm_metadata['emails'] = None
for i, row in tqdm(lm_metadata.iterrows(), miniters=1000):
    lm_metadata.at[i, 'emails'] = get_all_emails(row, fulltext_dir, n_lines_to_check)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 16979it [00:25, 662.13it/s]

# %%
# print idxs in 'emails' which are None
print("Number of papers w/o fulltext", len(lm_metadata[lm_metadata['emails'].isnull()].index.tolist()))
print("Number of papers w/o emails", len(lm_metadata[lm_metadata['emails'].apply(lambda x: x is None or len(x) == 0)].index.tolist()))
# Out:
# Number of papers w/o fulltext 10
# Number of papers w/o emails 2360

# %% [markdown]
# ### Add affiliation column

# %%
from preprocess_utils import add_affiliation_info

lm_metadata_affil = add_affiliation_info(lm_metadata)
display(lm_metadata_affil.sample(5))
# Out:
#                id                                    authors  \
# 15477  2307.07854  [Iman Saberi, Fatemeh Fard, Fuxiang Chen]
# 447    1904.02099             [Dan Kondratyuk, Milan Straka]
# 7744   2205.05807           [Patrick Wilken, Evgeny Matusov]
# 12377  2304.11852                            [Didier El Baz]
# 8359   2207.01672                          [Ramon Ruiz-Dolz]
#
#                                                    title      categories  \
# 15477  Multilingual Adapter-based Knowledge Aggregati...         [cs.SE]
# 447    75 Languages, 1 Model: Parsing Universal Depen...  [cs.CL, cs.LG]
# 7744   AppTek's Submission to the IWSLT 2022 Isometri...         [cs.CL]
# 12377  Can we Trust Chatbots for now? Accuracy, repro...         [cs.CY]
# 8359   A Cascade Model for Argument Mining in Japanes...         [cs.CL]
#
#                                                 abstract  \
# 15477    Multilingual fine-tuning (of a multilingual ...
# 447      We present UDify, a multilingual multi-task ...
# 7744     To participate in the Isometric Spoken Langu...
# 12377    Large Language Models (LLM) are studied. App...
# 8359     The rVRAIN team tackled the Budget Argument ...
#
#                                                 versions first_category  \
# 15477  [{'version': 'v1', 'created': 'Sat, 15 Jul 202...          cs.SE
# 447    [{'version': 'v1', 'created': 'Wed, 3 Apr 2019...          cs.CL
# 7744   [{'version': 'v1', 'created': 'Thu, 12 May 202...          cs.CL
# 12377  [{'version': 'v1', 'created': 'Mon, 24 Apr 202...          cs.CY
# 8359   [{'version': 'v1', 'created': 'Mon, 4 Jul 2022...          cs.CL
#
#              v1_date                                   LM_related_terms  \
# 15477  1689441436000                                   [language model]
# 447    1554310375000                                             [BERT]
# 7744   1652313744000                                             [BERT]
# 12377  1682319250000  [language model, large language model, ChatGPT...
# 8359   1656960558000                                             [BERT]
#
#        mentions_LM_keyword                                             emails  \
# 15477                 True  [iman.saberi@ubc.ca, fatemeh.fard@ubc.ca, fuxi...
# 447                   True                          [dankondratyuk@gmail.com]
# 7744                  True          [pwilken@apptek.com, ematusov@apptek.com]
# 12377                 True                                    [elbaz@laas.fr]
# 8359                  True                             [raruidol@dsic.upv.es]
#
#                          domains  industry  academic
# 15477  [ubc.ca, leicester.ac.uk]     False      True
# 447                           []     False     False
# 7744                [apptek.com]     False     False
# 12377                  [laas.fr]     False     False
# 8359               [dsic.upv.es]     False     False

# %% [markdown]
# ## Save the cleaned metadata files, one for all papers and one for LLM papers only

# %%
lm_metadata.sample(10)[['id', 'authors', 'title', 'emails']]
# Out:
#                  id                                            authors  \
# 1809103  2303.09306  [HAZ Sameen Shahgir, Ramisa Alam, Md. Zarif Ul...
# 1822098  2304.04052  [Zihao Fu, Wai Lam, Qian Yu, Anthony Man-Cho S...
# 1656802  2205.12390                   [Yau-Shian Wang, Yingshan Chang]
# 1231253  2001.05840  [Lei Shi, Shijie Geng, Kai Shuang, Chiori Hori...
# 1440505  2103.10360  [Zhengxiao Du, Yujie Qian, Xiao Liu, Ming Ding...
# 1591154  2201.05782         [Jibao Qiu, C. L. Philip Chen, Tong Zhang]
# 943760   1802.04220  [Francisco J. R. Ruiz, Michalis K. Titsias, Ad...
# 1361675  2010.05345  [Xikun Zhang, Deepak Ramachandran, Ian Tenney,...
# 1177021  1909.06983  [Fang Liu, Ge Li, Bolin Wei, Xin Xia, Zhiyi Fu...
# 1874947  2307.03952  [Yu Ji, Wen Wu, Hong Zheng, Yi Hu, Xi Chen, Li...
#
#                                                      title  \
# 1809103  BanglaCoNER: Towards Robust Bangla Complex Nam...
# 1822098  Decoder-Only or Encoder-Decoder? Interpreting ...
# 1656802  Toxicity Detection with Generative Prompt-base...
# 1231253  Multi-Layer Content Interaction Through Quater...
# 1440505  GLM: General Language Model Pretraining with A...
# 1591154  A Novel Multi-Task Learning Method for Symboli...
# 943760   Augment and Reduce: Stochastic Inference for L...
# 1361675             Do Language Embeddings Capture Scales?
# 1177021  A Self-Attentional Neural Architecture for Cod...
# 1874947  Is ChatGPT a Good Personality Recognizer? A Pr...
#
#                                                     emails
# 1809103                                                 []
# 1822098  [{zf268,nhc30}@cam.ac.uk, {wlam,manchoso}@se.c...
# 1656802                  [{yaushiaw, yingshac}@cs.cmu.edu]
# 1231253                                                 []
# 1440505     [kimi_yang@rcrai.com, jietang@tsinghua.edu.cn]
# 1591154  [csj.b.qiu@mail.scut.edu.cn, {philipchen, tony...
# 943760         [f.ruiz@eng.cam.ac.uk, f.ruiz@columbia.edu]
# 1361675  [xikunz2@cs.stanford.edu, ramachandrand@google...
# 1177021  [liufang816@pku.edu.cn, lige@pku.edu.cn, bolin...
# 1874947                                                 []

# %%
# Save metadata to json
metadata.to_json(os.path.join(PROCESSED_DATA_DIR, f'cs_stat_metadata_{metadata_date}.json'), 
                 orient='records', lines=True)
lm_metadata.to_json(os.path.join(PROCESSED_DATA_DIR, f'lm_papers_metadata_{metadata_date}.json'), 
                    orient='records', lines=True)

# %%
# All metadata, without date filtering
metadata.to_json(os.path.join(PROCESSED_DATA_DIR, f'fulldaterange_cs_stat_metadata_{metadata_date}.json'), 
                 orient='records', lines=True)
